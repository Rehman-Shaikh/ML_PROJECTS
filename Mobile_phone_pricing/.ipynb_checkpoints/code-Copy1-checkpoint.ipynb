# %% [markdown]
# #### **Import Libraries & Load Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Dataset load karo
df = pd.read_csv("dataset.csv")  # Replace with actual filename
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# #### **Explore Dataset (EDA – Exploratory Data Analysis)**

# %%
# 1. Dataset shape
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (2000, 21)

# %%
# 2. Info check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# Check for outliers
plt.figure(figsize=(15, 6))
sns.boxplot(data=df[['ram', 'battery_power', 'px_height', 'px_width']])
plt.title("Boxplot of Important Numeric Features")
plt.xticks(rotation=90)
plt.show()

# %%
Q1 = df['px_height'].quantile(0.25)
Q3 = df['px_height'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['px_height'] < lower_bound) | (df['px_height'] > upper_bound)]
print("Outliers in px_height:", outliers.shape[0])
# Out:
# Outliers in px_height: 2

# %%
df['px_height'] = np.where(df['px_height'] > upper_bound, upper_bound,
                  np.where(df['px_height'] < lower_bound, lower_bound, df['px_height']))

# %%
df = df[(df['px_height'] >= lower_bound) & (df['px_height'] <= upper_bound)]

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['px_height'])
plt.title("Boxplot of px_height")
plt.show()

# %% [markdown]
# - All columns are **complete** with no missing values.
# - Data types are mostly numeric: `int64` for discrete values and `float64` for continuous ones.

# %%
# 3. Target column distribution
sns.countplot(x='price_range', data=df)
plt.title("Distribution of Price Range")
plt.xlabel("Price Range (0=Low, 3=Very High)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# "Since all columns have the same size, our data is not biased with respect to the price range."

# %% [markdown]
# #### **Correlation Matrix (Feature Selection / Insights)**

# %% [markdown]
# #####  Why Use a Correlation Matrix?
#
# -  **Identify Relationships**
#   Understand how strongly features relate (values between -1 and 1)
#
# -  **Reduce Redundancy**
#   Remove highly correlated features to simplify the model

# %%
# 1. Correlation matrix
corr = df.corr()

# 2. Heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #####  Key Feature Correlations with `price_range`
#
# -  **RAM**: 0.92 → Strongest positive correlation
# -  **Battery Power**: 0.20
# -  **Pixel Width**: 0.17
# -  **Pixel Height**: 0.15
#  Useful features for model training
#
# ##### Multicollinearity Check (Input Features)
#
# -  `px_height` & `px_width`: 0.51
# -  `sc_h` & `sc_w`: 0.51
# -  `pc` & `fc`: 0.64 → Slightly high, but acceptable
#  No pairs above 0.90 → No serious multicollinearity issues

# %% [markdown]
# ####  **Data Preprocessing & Train-Test Split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Features & target
X = df.drop("price_range", axis=1)
y = df["price_range"]

# Train-test split (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
# stratify=y ensures test data me bhi class balance maintained rahe.

# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled.shape , y_train.shape
# Out:
# ((1600, 20), (1600,))

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
models = {
    "RandomForest": RandomForestClassifier(random_state=42),
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier()
}

# %%
results = {}

for name, model in models.items():
    print(f"Training and evaluating {name}...")
    scores = cross_val_score(model, X_train_scaled, y_train, cv=skf, scoring='accuracy')
    results[name] = scores
    print(f"{name} Mean CV Accuracy: {np.mean(scores):.4f}")
# Out:
# Training and evaluating RandomForest...
# RandomForest Mean CV Accuracy: 0.8631
# Training and evaluating LogisticRegression...
# LogisticRegression Mean CV Accuracy: 0.9525
# Training and evaluating SVM...
# SVM Mean CV Accuracy: 0.8625
# Training and evaluating KNN...
# KNN Mean CV Accuracy: 0.5031

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(results.values(), labels=results.keys())
plt.title("Model Comparison (CV Accuracy)")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}

logreg = LogisticRegression(max_iter=1000)
grid = GridSearchCV(logreg, param_grid, cv=skf, scoring='accuracy', n_jobs=-1)

# %%
grid.fit(X_train_scaled, y_train)

print("Best Parameters:", grid.best_params_)
print("Best CV Score:", grid.best_score_)
# Out:
# Best Parameters: {'C': 100, 'penalty': 'l1', 'solver': 'saga'}
# Best CV Score: 0.97

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Predict test set
y_pred = grid.predict(X_test_scaled)

print("Test Set Classification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix – Tuned Logistic Regression")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Test Set Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98       105
#            1       0.95      1.00      0.97        91
#            2       0.99      0.98      0.98        92
#            3       0.98      0.99      0.99       112
#
#     accuracy                           0.98       400
#    macro avg       0.98      0.98      0.98       400
# weighted avg       0.98      0.98      0.98       400

# %%
# !pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached shap-0.48.0-cp312-cp312-win_amd64.whl.metadata (25 kB)
# ...
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# ...
# Using cached shap-0.48.0-cp312-cp312-win_amd64.whl (545 kB)
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# ...

# %%
from sklearn.linear_model import LogisticRegression

# Train directly for SHAP compatibility
best_logreg = LogisticRegression(C=100, penalty='l1', solver='saga', max_iter=1000)
best_logreg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=100, max_iter=1000, penalty='l1', solver='saga')

# %%
import shap

# Create explainer
explainer = shap.LinearExplainer(best_logreg, X_train_scaled, feature_perturbation="interventional")
shap_values = explainer.shap_values(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 import shap
#       3 # Create explainer
#       4 explainer = shap.LinearExplainer(best_logreg, X_train_scaled, feature_perturbation="interventional")
#
# ModuleNotFoundError: No module named 'shap'
